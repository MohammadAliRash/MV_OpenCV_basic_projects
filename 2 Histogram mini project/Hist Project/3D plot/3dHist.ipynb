# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits import mplot3d

# %%
#reading img
new_img2 = cv2.imread('2.jpg')

#convering to HSV
HLS_img = cv2.cvtColor(new_img2, cv2.COLOR_BGR2HLS)
plt.imshow(HLS_img)
plt.imsave('HLS_img.jpg', HLS_img)

# %%
hist_vals_HLS_0 = cv2.calcHist([HLS_img], channels=[0], mask=None, histSize=[255], ranges=[0,255])


hist_vals_HLS_1 = cv2.calcHist([HLS_img], channels=[1], mask=None, histSize=[255], ranges=[0,255])


hist_vals_HLS_2 = cv2.calcHist([HLS_img], channels=[2], mask=None, histSize=[255], ranges=[0,255])

# %%
fig = plt.figure(dpi=120)
ax = plt.axes(projection='3d')
z = hist_vals_HLS_0
x = hist_vals_HLS_1
y = hist_vals_HLS_2

ax.plot3D(x, y, z, 'gray')
ax.set_title('3D line plot')

ax.set_xlim(0, 255)
ax.set_ylim(0, 255)
ax.set_zlim(0, 255)

ax.set_xlabel('H axis')
ax.set_ylabel('L axis')
ax.set_zlabel('S axis')
plt.show()

plt.imsave('3Dplot.jpg', ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 19
#      16 ax.set_zlabel('S axis')
#      17 plt.show()
# ---> 19 plt.imsave('3Dplot.jpg', ax)
#
# File ~\.conda\envs\firstPanda\Lib\site-packages\matplotlib\pyplot.py:2200, in imsave(fname, arr, **kwargs)
#    2198 @_copy_docstring_and_deprecators(matplotlib.image.imsave)
#    2199 def imsave(fname, arr, **kwargs):
# -> 2200     return matplotlib.image.imsave(fname, arr, **kwargs)
#
# File ~\.conda\envs\firstPanda\Lib\site-packages\matplotlib\image.py:1658, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 else:
#    1656     # we modify this below, so make a copy (don't modify caller's dict)
#    1657     pil_kwargs = pil_kwargs.copy()
# -> 1658 pil_shape = (rgba.shape[1], rgba.shape[0])
#    1659 image = PIL.Image.frombuffer(
# ...
